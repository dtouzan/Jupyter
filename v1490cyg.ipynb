# %% [markdown]
# [![Le Baladin](https://img.shields.io/badge/Le_baladin-Report_photométrique_étoile_variable_V1490_Cyg-blue.svg)](https://sites.google.com/view/astronomie-ut1/accueil)
#
# _Dominique Touzan_<sup>1,2</sup>
#
# <sup>1</sup>Notebook: https://anaconda.org/dtouzan/v1490cyg/notebook
#
# <sup>2</sup>Correspondance: [dtouzan@gmail.com](mailto:dtouzan@gmail.com)
#
# Édition   1.0, révision 21/12/2019
#
# ---
# **Résumé** : Fin septembre et tout début d’automne 2019 la constellation du Cygne est bien présente  sur la voûte céleste, L’étoile Deneb est proche du zénith au alentour de vingt-deux heures. Très proche à l’Est de celle-ci se trouve IC 5070 la nébuleuse du Pélican. Visualisation et report photométrique de l'étoile variable v1490 Cyg durant la période d'octobre 2019. Quinze mesures avec un filtre CLS CCD en début de soirée avec des jours de pleine lune ou de lune gibeuse et un temps relativement calme. Les valeurs reportées sont bien évidemment représentatifs du filtre utilisé.
#
# _Mots-clés_ : Etoile variable - Photométrie
#
# ---
# [![astropy](http://img.shields.io/badge/powered%20by-AstroPy-orange.svg?style=flat)](http://www.astropy.org/)

# %% [markdown]
# ## Introduction
# Les observations ont été effectuées avec le télescope Intes M603. La caméra CCD utilisée est la Atik Titan la configuration de celle-ci est de 659 x 494 pixels de 7,4 µm avec un refroidissement non régulé. La résolution avec le télescope Intes M603 d’une focale de 1 mètre est de 1,6" arc sec / pixel, Un réducteur de focale Celestron est utilisé pour pouvoir descendre la focale à 1 mètre (F/D 6,7). La monture est une Sky-Watcher AZ-EQ5. Le suivi automatique étant assuré par un télescope LC90 et une caméra PL-1M. Les prises de vue sont réalisées essentiellement en début de nuit entre vingt-deux heures et minuit.
#
# Le logiciel CCDCiel est utilisé pour la prise de vue, pour le suivi automatique PHD2 est nécessaire (binning deux avec la PL-1M) pour un bon suivi de la monture. Les temps de pose cumulés d’une heure cumulé sont faciles à réaliser avec la monture. Les images sont  réalisées en utilisant la fonction « médian » sous le logiciel Iris[[1]](#ref1). L’orientation des images est calibrée le nord en haut et l’est à gauche. Les prévisualisations des images ont été élaborées avec le logiciel Aladin pour le repérage des étoiles variables et la calibration astrométrique.

# %% [markdown]
# ## Positions des prises de vue de l'observatoire UT1 sur une projection Aitoff.
# Les marqueurs indiquent les positions des différentes images prise à l'observatoire. Un fichier au format MAST **(mast.stsci.edu)** est lu et mis en forme pour reporter les observations indiquées en bleu, un autre fichier lui reporte différentes constellations ainsi que la LMC et SMC. Pour faciliter la mise en position du télescope les champs des prises de vue ont été reportée sur Aladin Sky Atlas[[2]](#ref2)</sup> en pointant IC 5070 puis en sélectionnant le champ de l'instrument via le menu "charger un champ instrumental (FoV)...".

# %%
from astrolebaladin import *

# %%
Projections('v1490 Cyg', 'UT1 observations','v1490cyg-cds.jpg', 'IC 5070. Nébuleuse du Pélican')

# %% [markdown]
# _Fig. 1._ La marque rouge indique la position de l'étoile variable

# %% [markdown]
# ## Hauteurs de l'étoile variable à l'observatoire UT1.
# La hauteur de v1490 Cyg vers 0h UT est proche du zénith, la constellation du cygne est bien accéssible pour le site cependant certaines soirées sont délicates car le temps ne se prête guère à l'observation et la Lune ne permet pas de bonnes prise de vue quand celle ci est illuminée au dessus de 50%.

# %%
# Dates des observations
dates_obs = ['2019-08-29T20:00:00','2019-08-30T20:00:00','2019-09-05T20:00:00','2019-09-08T20:00:00',
             '2019-09-10T20:00:00','2019-09-12T20:00:00','2019-09-14T20:00:00','2019-09-15T20:00:00',
             '2019-09-17T20:00:00','2019-09-18T20:00:00','2019-09-19T20:00:00','2019-09-20T20:00:00',
             '2019-09-22T20:00:00','2019-09-27T20:00:00']

# % illumination de la Lune
moon_phase = [0,0,25,50,50,75,100,100,75,75,50,50,25,0]

Elevationsplot('v1490cyg', dates_obs, moon_phase, 25)

# %% [markdown]
# _Fig. 2._ Hauteur de v1490 Cyg et illumination et hauteur de la Lune pour les quatorze soirées.

# %% [markdown]
# ## Observation: L'étoile variable dans la nébuleuse IC 5070 (Nébuleuse du Pélican).
# Pour indiquer le repérage les images des soirées ont d'abord été calibrées avec le logiciel **Iris** puis additionées, pour la première image une addition de vingt images de 180 secondes du 22 octobre 2019 et pour la deuxième une addition de soixante-neuf images de 180 secondes des soirées du 29 et 30 septembre 2019, puis avec le logiciel **Aladin Sky Atlas** une calibration astrométrique est appliquée pour indiquer les coordonées **WCS**.

# %%
Spot('v1490cyg', 'v1490cyg-20190922.fits', 200,450,'1','v1490cyg-1.jpg','Image en négatif')
Spot('v1490cyg', 'v1490cyg-20190829.fits', 15000,25000,'2','v1490cyg-2.jpg','Image en négatif')

# %% [markdown]
# _Fig. 3._ Image des soirées du 22/09/2019 à 20h17mn (1) et du 29/09/2019 et 30/09/2019 (2).

# %% [markdown]
# ## Carte de champs.
# Réalisée avec Astroquery et Aplpy en utilisant les catalogues GSC 2.3, CMC15, UCAC5. L'interrogation se fait sur le service VizieR du CDS[[2]](#ref2). Les magnitudes indiquées sont celles du catalogue APASS-AAVSO

# %%
FieldMap('V1490 CYG',312.78,44.42,'v1490cyg-20190922.fits',0.20,10,17)

# %% [markdown]
# _Fig. 4._ La marque indique la position de l'étoile variable

# %% [markdown]
# ## Report des mesures.
# Pour ces quinze mesures l'étoile de référence était UCAC4 672-086818 et une deuxième étoile UCAC4 672-086809 a été prise pour améliorer la précision des mesures. Peu de mesure pour cette étoile dans le catalogue de l'AAVSO[[3]](#ref3) a cette période. Une courbe se dessine relativement bien pour les dates du 12 au 27 octobre avec un minimum le 10 octobre 2019, tout ceci avec un filtre CLS CCD qui n'est pas le plus adapté pour ce type d'observation car une des valeurs de l'AAVSO est plus basse de 0.15 par rapport aux mesures du 22 octobre 2019.

# %%
# Magnitudeplot(fichier photometrie csv, localisation de la légende)
Magnitudeplot('v1490cyg_UT1.csv', 'center left')

# %% [markdown]
# _Fig. 5._ Graphique des magnitudes enregistrées.

# %% [markdown]
# ## Différence de magnitude de v1490 Cyg.
# Quatre des images les plus représentatives de la magnitude élévée sont les 8, 9, 10 et 11. Chaque image est une médiane de onze images (l'étoile est au centre en bas de l'image). Le temps de pose est de 180 secondes
#
# Images 08. 15/09/2019 à 19h23mn, 09. 17/09/2019 à 19h26mn, 10. 18/08/2019 à 19h38mn, 11. 19/09/2019 à 19h22mn

# %%
SpotJPEG(['20190829.jpg','20190830.jpg','20190905.jpg','20190908.jpg','20190910.jpg','20190912.jpg','20190914.jpg',
          '20190915.jpg','20190917.jpg','20190918.jpg','20190919.jpg','20190920.jpg','20190922.jpg','20190927.jpg'],3,5)

# %% [markdown]
# _Fig. 6._ Images des différentes magnitudes.
#
# _Table. 1._ Données de prise de vue et données CDS.

# %%
EditVariableData('v1490cyg_UT1.csv')
# Out:
#       JD          Name   RA(j2000) 	 Dec(j2000) Exposure (s) Band   Mg
# -------------- --------- ---------------------- ------------ ---- -----
# 2458725.348610 V1490 CYG 20h50m53.6s +44d21m01s          180  CLS 15.84
# 2458726.359720                                           180  CLS 15.83
# 2458732.333330                                           180  CLS 15.42
# 2458735.325000                                           180  CLS 15.45
# 2458737.330550                                           180  CLS 15.85
# 2458739.328470                                           180  CLS 15.32
# 2458741.311100                                           180  CLS 15.22
# 2458742.307630                                           180  CLS 15.19
# 2458744.309720                                           180  CLS 15.17
# 2458745.309720                                           180  CLS 15.17
# 2458746.306940                                           180  CLS 15.19
# ...

# %% [markdown]
# ## Références
# ---
# <a id='ref1'></a>
# 1. Iris, http://www.astrosurf.com/buil/iris-software.html
# <a id='ref2'></a>
# 2. CDS Portal, http://cdsportal.u-strasbg.fr
# <a id='ref3'></a>
# 3. AAVSO, The American Association of Variable Star Observers, https://www.aavso.org/Iris.

# %%
QRsign()
